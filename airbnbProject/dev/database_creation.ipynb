# %% [markdown]
# ### Example of ETL

# %%
# Dependencies
import pandas as pd
import seaborn as sns

from sqlalchemy import create_engine

# %%
# Create database connection
connection_string= 'postgresql+psycopg2://postgres:alvin1997@localhost:5432/airbnb_project'
engine = create_engine(connection_string)

# %%
data = pd.read_csv("./Resources/air_bnb_data.csv")

# %%
data
# Out:
#             id                                               name    host_id  \
# 0        12937  1 Stop fr. Manhattan! Private Suite,Landmark B...      50124
# 1        18198                              Little King of Queens      70091
# 2        32363                 Fully Furnished Basement Apartment     140025
# 3        39593            A room w/ a Manhattan view, longer stay     110506
# 4        45910                 Beautiful Queens Brownstone! - 5BR     204539
# ...        ...                                                ...        ...
# 5661  36458668  2beds Private Room Step to LGA, CitiFiled, Mid...  217463199
# 5662  36469741                Comfortable & Big room with 2 beds!  274012871
# 5663  36472710                                 CozyHideAway Suite  274225617
# 5664  36479723                                      Room for rest   41326856
# 5665  36484363                                 QUIT PRIVATE HOUSE  107716952
#
# ...

# %%
# This is just a test to see if I have a connection to postgresql
# pd.read_sql('select * from actor', engine)

# %%
data.to_sql('airbnb', engine, index=False)
# Out:
# 666
